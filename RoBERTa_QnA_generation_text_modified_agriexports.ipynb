# %% [markdown]
# <a href="https://colab.research.google.com/github/preetamjumech/LLM/blob/main/RoBERTa_QnA_generation_text_modified_agriexports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/text analytics 1/q a 1/2011_US_AGRI_Exports.csv")
df.head()
# Out:
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton  \
# 0          14.33  34.9   70.0   317.61
# ...

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (50, 18)

# %%
df
# Out:
#    code           state category  total exports   beef    pork  poultry  \
# 0    AL         Alabama    state        1390.63   34.4    10.6    481.0
# 1    AK          Alaska    state          13.31    0.2     0.1      0.0
# 2    AZ         Arizona    state        1463.17   71.3    17.9      0.0
# 3    AR        Arkansas    state        3586.02   53.2    29.4    562.9
# 4    CA      California    state       16472.88  228.7    11.1    225.4
# 5    CO        Colorado    state        1851.33  261.4    66.0     14.0
# 6    CT     Connecticut    state         259.62    1.1     0.1      6.9
# 7    DE        Delaware    state         282.19    0.4     0.6    114.7
# 8    FL         Florida    state        3764.09   42.6     0.9     56.9
# 9    GA         Georgia    state        2860.84   31.0    18.9    630.4
# 10   HI          Hawaii    state         401.84    4.0     0.7      1.3
# 11   ID           Idaho    state        2078.89  119.8     0.0      2.4
# ...

# %%
import re

# %%
def removedot(text):
    text = re.sub('\.','',text)
    return text

# %%
'''df["Name1"] = df.Name.apply(removedot)'''

# %%
def removeslash(text):
    text = re.sub('/',' ',text)
    return text

# %%
'''df["Industry1"] = df.Industry.apply(removeslash)'''
# Out:
# C:\Users\Preetam\AppData\Local\Temp\ipykernel_7664\1001666918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Industry1"] = df.Industry.apply(removeslash)

# %%
df
# Out:
#    code           state category  total exports   beef    pork  poultry  \
# 0    AL         Alabama    state        1390.63   34.4    10.6    481.0
# 1    AK          Alaska    state          13.31    0.2     0.1      0.0
# 2    AZ         Arizona    state        1463.17   71.3    17.9      0.0
# 3    AR        Arkansas    state        3586.02   53.2    29.4    562.9
# 4    CA      California    state       16472.88  228.7    11.1    225.4
# 5    CO        Colorado    state        1851.33  261.4    66.0     14.0
# 6    CT     Connecticut    state         259.62    1.1     0.1      6.9
# 7    DE        Delaware    state         282.19    0.4     0.6    114.7
# 8    FL         Florida    state        3764.09   42.6     0.9     56.9
# 9    GA         Georgia    state        2860.84   31.0    18.9    630.4
# 10   HI          Hawaii    state         401.84    4.0     0.7      1.3
# 11   ID           Idaho    state        2078.89  119.8     0.0      2.4
# ...

# %%
df.sample(5)
# Out:
#    code        state category  total exports   beef  pork  poultry   dairy  \
# 8    FL      Florida    state        3764.09   42.6   0.9     56.9   66.31
# 4    CA   California    state       16472.88  228.7  11.1    225.4  929.95
# 18   ME        Maine    state         278.37    1.4   0.5     10.4   16.18
# 6    CT  Connecticut    state         259.62    1.1   0.1      6.9    9.49
# 43   UT         Utah    state         453.39   27.9  59.0     23.1   48.60
#
#     fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 8          438.2        933.1       1371.36          171.9         279.0
# 4         2791.8       5944.6       8736.40          803.2        1303.5
# 18          16.6         35.4         52.01           24.0          38.9
# 6            4.2          8.9         13.10            4.3           6.9
# 43           3.9          8.4         12.34            2.5           4.1
#
#     total veggies  corn  wheat   cotton  \
# ...

# %%
df.columns
# Out:
# Index(['code', 'state', 'category', 'total exports', 'beef', 'pork', 'poultry',
#        'dairy', 'fruits fresh', 'fruits proc', 'total fruits', 'veggies fresh',
#        'veggies proc', 'total veggies', 'corn', 'wheat', 'cotton', 'text'],
#       dtype='object')

# %%
code = row['code']
    state = row["state"]
    texp = row["total exports"]
    beef = row["beef"]
    pork = row["poultry"]
    dairy = row["dairy"]
    freshfruits = row["fruits fresh"]
    cotton=row['cotton']

# %%
def generate_txt(row):
    code = row['code']
    state = row["state"]
    texp = row["total exports"]
    beef = row["beef"]
    pork = row["poultry"]
    dairy = row["dairy"]
    freshfruits = row["fruits fresh"]
    cotton=row['cotton']
    text = f''''{state}' {np.random.choice(["is a state ","is the name of a state "])} {np.random.choice(["that has the code","having the code"])} '{code}' and this state's total exports is {texp},out of which {np.random.choice([f'beef constitutes {beef},pork {pork},dairy {dairy} and freshfruits constitute {freshfruits}.',f'beef constitutes {beef},dairy {dairy},pork {pork}, and freshfruits constitute {freshfruits}.',f'dairy constitutes {dairy},beef {beef},pork {pork}, and freshfruits constitute {freshfruits}.',f'dairy constitutes {dairy},beef {beef},freshfruits {freshfruits}, and pork constitute {pork}.'])}'''
    return text

# %%
df['text']=df.apply(generate_txt,axis = 1)

# %%
text=('\n').join(df.text)

# %%
text
# Out:
# "'Alabama' is a state  that has the code 'AL' and this state's total exports is 1390.63,out of which beef constitutes 34.4,pork 481.0,dairy 4.06 and freshfruits constitute 8.0.\n'Alaska' is the name of a state  that has the code 'AK' and this state's total exports is 13.31,out of which dairy constitutes 0.19,beef 0.2,pork 0.0, and freshfruits constitute 0.0.\n'Arizona' is a state  that has the code 'AZ' and this state's total exports is 1463.17,out of which dairy constitutes 105.48,beef 71.3,freshfruits 19.3, and pork constitute 0.0.\n'Arkansas' is the name of a state  having the code 'AR' and this state's total exports is 3586.02,out of which beef constitutes 53.2,dairy 3.53,pork 562.9, and freshfruits constitute 2.2.\n' California' is a state  having the code 'CA' and this state's total exports is 16472.88,out of which beef constitutes 228.7,pork 225.4,dairy 929.95 and freshfruits constitute 2791.8.\n'Colorado' is the name of a state  having the code 'CO' and this state's total exp
# ...

# %%
with open("agri_text_generation10.txt","w")as f:
    f.write(text)

# %%
df1=df.sample(10)

# %%
df1
# Out:
#    code           state category  total exports   beef    pork  poultry  \
# 30   NM      New Mexico    state         751.58  117.2     0.1      0.3
# 38   RI    Rhode Island    state          31.59    0.1     0.1      0.2
# 32   NC  North Carolina    state        3806.05   24.8   702.8    598.4
# 17   LA       Louisiana    state        1914.23   19.8     0.8     77.2
# 15   KS          Kansas    state        4589.01  659.3   179.4      6.4
# 36   OR          Oregon    state        1794.57   58.8     1.4     14.2
# 20   MA   Massachusetts    state         248.65    0.6     0.5      0.6
# 4    CA      California    state       16472.88  228.7    11.1    225.4
# 14   IA            Iowa    state       11273.76  289.8  1895.6    155.6
# 39   SC  South Carolina    state         929.93   15.2    10.9    186.5
#
#      dairy  fruits fresh  fruits proc  total fruits  veggies fresh  \
# 30  191.01          32.6         69.3        101.90           16.7
# ...

# %%
questions=[
    "What is the total exports for South Carolina?",
    "How much beef does Lowa export?",
    "How much dairy does Kansas export?",
    "What is the total exports for Louisiana?",
    "What is the code for Kansas?",
    "How much pork does North Carolina export?",
    "How much fresh fruits does New Mexico export?",
    "How much beef does Oregon export?"
]

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 50.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 72.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.8 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForQuestionAnswering

# %%
model=AutoModelForQuestionAnswering.from_pretrained('deepset/roberta-base-squad2')

# %%
from transformers import AutoTokenizer
tokenizer=AutoTokenizer.from_pretrained('deepset/roberta-base-squad2')
tokenizer.encode(questions[0],truncation=False,padding=True)
# Out:
# ...
# [0, 2264, 16, 5, 746, 4302, 13, 391, 1961, 116, 2]

# %%
from transformers import pipeline
nlp=pipeline('question-answering',model=model,tokenizer=tokenizer)

# %%
df1

# %%
print(questions[0],":")
nlp({
    'question':questions[0],
     'context': text
  })
# Out:
# What is the total exports for South Carolina? :
# {'score': 0.6968845725059509, 'start': 7217, 'end': 7223, 'answer': '929.93'}

# %%
print(questions[1],":")
nlp({
    'question':questions[1],
     'context': text
  })
# Out:
# How much beef does Lowa export? :
# {'score': 0.04303747043013573, 'start': 1910, 'end': 1916, 'answer': '401.84'}

# %%
print(questions[2],":")
nlp({
    'question':questions[2],
     'context': text
  })
# Out:
# How much dairy does Kansas export? :
# {'score': 0.07262752205133438,
#  'start': 2798,
#  'end': 2842,
#  'answer': '4589.01,out of which dairy constitutes 65.45'}

# %%
df1[df1.state=='Kansas']
# Out:
#    code   state category  total exports   beef   pork  poultry  dairy  \
# 15   KS  Kansas    state        4589.01  659.3  179.4      6.4  65.45
#
#     fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 15           1.0          2.1          3.11            3.6           5.8
#
#     total veggies   corn   wheat  cotton  \
# 15           9.32  457.3  1426.5   43.98
#
#                                                  text
# 15  'Kansas' is a state  that has the code 'KS' an...

# %%
print(questions[3],":")
nlp({
    'question':questions[3],
     'context': text
  })
# Out:
# What is the total exports for Louisiana? :
# {'score': 0.8777518272399902, 'start': 3164, 'end': 3171, 'answer': '1914.23'}

# %%
df1[df1.state=='Louisiana']
# Out:
#    code      state category  total exports  beef  pork  poultry  dairy  \
# 17   LA  Louisiana    state        1914.23  19.8   0.8     77.2   6.02
#
#     fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 17           5.7         12.1         17.83            6.6          10.7
#
#     total veggies  corn  wheat  cotton  \
# 17          17.25  91.4   78.7  280.42
#
#                                                  text
# 17  'Louisiana' is the name of a state  having the...

# %%
print(questions[4],":")
nlp({
    'question':questions[4],
     'context': text
  })
# Out:
# What is the code for Kansas? :
# {'score': 0.2555362284183502, 'start': 2760, 'end': 2762, 'answer': 'KS'}

# %%
print(questions[5],":")
nlp({
    'question':questions[5],
     'context': text
  })
# Out:
# How much pork does North Carolina export? :
# {'score': 0.08657464385032654, 'start': 4698, 'end': 4701, 'answer': '1.7'}

# %%
df1[df1.state=='North Carolina']
# Out:
#    code           state category  total exports  beef   pork  poultry  dairy  \
# 32   NC  North Carolina    state        3806.05  24.8  702.8    598.4   24.9
#
#     fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 32          23.8         50.7         74.47           57.4          93.1
#
#     total veggies  corn  wheat  cotton  \
# 32         150.45  92.2  200.3  470.86
#
#                                                  text
# 32  'North Carolina' is the name of a state  havin...

# %%
print(questions[6],":")
nlp({
    'question':questions[6],
     'context': text
  })
# Out:
# How much fresh fruits does New Mexico export? :
# {'score': 0.17346841096878052, 'start': 4730, 'end': 4733, 'answer': '1.1'}

# %%
df1[df1.state=='New Mexico']
# Out:
#    code       state category  total exports   beef  pork  poultry   dairy  \
# 30   NM  New Mexico    state         751.58  117.2   0.1      0.3  191.01
#
#     fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 30          32.6         69.3         101.9           16.7          27.1
#
#     total veggies  corn  wheat  cotton  \
# 30          43.88  11.2   13.9   72.62
#
#                                                  text
# 30  'New Mexico' is a state  that has the code 'NM...

# %%
print(questions[7],":")
nlp({
    'question':questions[7],
     'context': text
  })
# Out:
# How much beef does Oregon export? :
# {'score': 0.21134108304977417, 'start': 6709, 'end': 6713, 'answer': '58.8'}

# %%
df1[df1.state=='Oregon']
# Out:
#    code   state category  total exports  beef  pork  poultry  dairy  \
# 36   OR  Oregon    state        1794.57  58.8   1.4     14.2  63.66
#
#     fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 36         100.7        214.4        315.04           48.2          78.3
#
#     total veggies  corn  wheat  cotton  \
# 36          126.5  11.7  320.3     0.0
#
#                                                  text
# 36  'Oregon' is the name of a state  that has the ...
